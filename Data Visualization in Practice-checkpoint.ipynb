# %% [markdown]
# Our main goal in this section:
# 1. understand how Hans Rosling and the Gapminder Foundation use effective data visualization to convey data-based trends.
# 2. using ggplot2 to create plots that help us better understand trends in world health and economics.
# 3. learn how to augment the code to perfect the plots and learn concepts such as faceting, time series plots, transformations, and ridge plots.

# %% [markdown]
# # 1. Case study: A new insight into world health and economics

# %% [markdown]
# Data visualization can be used to dispel common myths and educate the public and contradict sensationalist or outdated claims and stories.
# We will use real data to answer the following questions about world health and economics:
# 1. Is it still fair to consider the world as divided into the West and the developing world?
# 2. Has income inequality across countries worsened over the last 40 years?

# %% [markdown]
# ### Access to the data set Gapminder

# %% [markdown]
# A selection of world health and economics statistics from the Gapminder project can be found in the dslabs package as data(gapminder). We can access the table like this:

# %%
library(dslabs)
data(gapminder)
head(gapminder)
# Out:
#   country             year infant_mortality life_expectancy fertility
# 1 Albania             1960 115.40           62.87           6.19
# 2 Algeria             1960 148.20           47.50           7.65
# 3 Angola              1960 208.00           35.98           7.32
# 4 Antigua and Barbuda 1960     NA           62.97           4.43
# 5 Argentina           1960  59.87           65.39           3.11
# 6 Armenia             1960     NA           66.86           4.55
#   population gdp          continent region
# 1  1636054             NA Europe    Southern Europe
# 2 11124892    13828152297 Africa    Northern Africa
# 3  5270844             NA Africa    Middle Africa
# 4    54681             NA Americas  Caribbean
# 5 20619075   108322326649 Americas  South America
# 6  1867396             NA Asia      Western Asia

# %%
gapminder %>%
    filter(year == 2015 & country %in% c("Sri Lanka", "Turkey")) %>%
    select(country, infant_mortality)
# Out:
#   country   infant_mortality
# 1 Sri Lanka  8.4
# 2 Turkey    11.6

# %% [markdown]
# ### Scatterplots: Life Expectancy and Fertility Rates

# %% [markdown]
# A prevalent worldview is that the world is divided into two groups of countries:
# 1. Western world: high life expectancy, low fertility rate
# 2. Developing world: lower life expectancy, higher fertility rate
#
# We first do a scatterplot of life expectancy versus fertility rates using the data from about 50 years ago.

# %% [markdown]
# Most points fall into two distinct categories:
# 1. Life expectancy around 70 years and 3 or less children per family.
# 2. Life expectancy lower then 65 years and more than 5 children per family.

# %%
# basic scatterplot of life expectancy versus fertility
ds_theme_set()    # set plot theme
filter(gapminder, year == 1962) %>%
    ggplot(aes(fertility, life_expectancy)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# Use color to differentiate countries from different regions.

# %%
# add color as continent
filter(gapminder, year == 1962) %>%
    ggplot(aes(fertility, life_expectancy, color = continent)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# # 2. Faceting: stratify the data by variables

# %% [markdown]
# Faceting makes multiple side-by-side plots stratified by some variable. This is a way to ease comparisons.

# %% [markdown]
# The facet_grid() function allows faceting by up to two variables, with rows faceted by one variable and columns faceted by the other variable.

# %%
# facet by continent and year
filter(gapminder, year %in% c(1962, 2012)) %>%
    ggplot(aes(fertility, life_expectancy, col = continent)) +
    geom_point() +
    facet_grid(continent ~ year)
# Out:
# plot without title

# %% [markdown]
# To facet by only one variable, use the dot operator as the other variable.

# %%
# facet by year only
filter(gapminder, year %in% c(1962, 2012)) %>%
    ggplot(aes(fertility, life_expectancy, col = continent)) +
    geom_point() +
    facet_grid(. ~ year)
# Out:
# plot without title

# %% [markdown]
# #### facet_wrap makes readable plot for transformations through the years

# %% [markdown]
# The facet_wrap() function facets by one variable and automatically wraps the series of plots so they have readable dimensions.

# %%
# facet by year, plots wrapped onto multiple rows
years <- c(1962, 1980, 1990, 2000, 2012)
continents <- c("Europe", "Asia")
gapminder %>%
    filter(year %in% years & continent %in% continents) %>%
    ggplot(aes(fertility, life_expectancy, col = continent)) +
    geom_point() +
    facet_wrap(~year)
# Out:
# plot without title

# %% [markdown]
# #### Remark: Fixed scales for better comparisons.

# %% [markdown]
# When not using facet, this range is determined
# by the data shown in the plot. When using facet, this range is determined by the data shown in all plots
# and therefore kept fixed across plots. This makes comparisons across plots much easier.

# %% [markdown]
# # 3. Time series plots

# %%
# scatterplot of US fertility by year
gapminder %>%
    filter(country == "United States") %>%
    ggplot(aes(year, fertility)) +
    geom_point()
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %%
# line plot of US fertility by year
gapminder %>%
    filter(country == "United States") %>%
    ggplot(aes(year, fertility)) +
    geom_line()
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_path)."
# plot without title

# %%
# line plot fertility time series for two countries- only one line (incorrect)
countries <- c("South Korea", "Germany")
gapminder %>% filter(country %in% countries) %>%
    ggplot(aes(year, fertility)) +
    geom_line()
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_path)."
# plot without title

# %%
#line plot fertility time series for two countries - one line per country
gapminder %>% filter(country %in% countries) %>%
    ggplot(aes(year, fertility, group = country)) +
    geom_line()
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_path)."
# plot without title

# %%
# fertility time series for two countries - lines colored by country
gapminder %>% filter(country %in% countries) %>%
    ggplot(aes(year, fertility, col = country)) +
    geom_line()
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_path)."
# plot without title

# %%
# life expectancy time series - lines colored by country and labeled, no legend
labels <- data.frame(country = countries, x = c(1975, 1965), y = c(60, 72))
gapminder %>% filter(country %in% countries) %>%
    ggplot(aes(year, life_expectancy, col = country)) +
    geom_line() +
    geom_text(data = labels, aes(x, y, label = country), size = 5) +
    theme(legend.position = "none")
# Out:
# plot without title
